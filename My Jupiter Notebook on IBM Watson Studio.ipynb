# %% [markdown]
# <H1> My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Carlos Andres Pemberthy Alzate </b>
#
# CFO

# %% [markdown]
# <i> I am interested in Data Science because nowadays, even in future, all companies can increase their profit using information thay they have about costumers, market, products, etc.  Also, I am convinced that all desition that you have to make, must be based on data and facts.  In this case Data Science gives the insights for make those decitions. </i>

# %% [markdown]
# <H3> The code in this notebook takes two variables and print the greatest

# %%
a=5
b=10
c=max(a,b)
print(c)
# Out:
# 10

# %% [markdown]
# This cell must includ at least 3 of the Following
# <ul>
#     <li> Horizontal rule. </li>
#     <li> Bullet list </li>
#     <li> Numbered list </li>
# </ul>
# Or even
# <ol>
#     <li> Tables </li>
#     <li> Hyperlinks </li>
#     <li> Images </li>
#     <li> Code/Syntax highlighting </li>
#     <li> Blocked quotes </li>
#     <li> Strikethrough </li>
# </ol>
#
# If you need some help abuot HTML languages and sintax you can visit <a href="https://www.w3schools.com/html/default.asp"> <b> HTML Tutorials </b> </a> on W3 Schools.
